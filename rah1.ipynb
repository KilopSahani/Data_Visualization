# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/batch1/Downloads/16eaf0b5-236c-411f-8a3d-1fd3e89f3b12.csv")

# %%
print(df)
# Out:
#    Sl. No.                                  State/UT  \
# 0        1                            Andhra Pradesh
# 1        2                         Arunachal Pradesh
# 2        3                                     Assam
# 3        4                                     Bihar
# 4        5                              Chhattisgarh
# 5        6                                       Goa
# 6        7                                   Gujarat
# 7        8                                   Haryana
# 8        9                          Himachal Pradesh
# 9       10                         Jammu and Kashmir
# 10      11                                 Jharkhand
# 11      12                                 Karnataka
# 12      13                                    Kerala
# 13      14                                    Ladakh
# 14      15                            Madhya Pradesh
# 15      16                               Maharashtra
# 16      17                                   Manipur
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of    Sl. No.                                  State/UT  \
# 0        1                            Andhra Pradesh
# 1        2                         Arunachal Pradesh
# 2        3                                     Assam
# 3        4                                     Bihar
# 4        5                              Chhattisgarh
# 5        6                                       Goa
# 6        7                                   Gujarat
# 7        8                                   Haryana
# 8        9                          Himachal Pradesh
# 9       10                         Jammu and Kashmir
# 10      11                                 Jharkhand
# 11      12                                 Karnataka
# 12      13                                    Kerala
# 13      14                                    Ladakh
# 14      15                            Madhya Pradesh
# 15      16                               Maharashtra
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['State/UT'])
plt.plot(df['Persons Who Availed Employment (in Lakh)'])

plt.xlabel('State/UT')
plt.ylabel('Persons Who Availed Employment (in Lakh)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar('State/UT','Persons Who Availed Employment (in Lakh)')
# Out:
# <BarContainer object of 1 artists>

# %%
name = df['State/UT']
person_emp = df['Persons Who Availed Employment (in Lakh)']
 
# Figure Size
fig = plt.figure(figsize =(40, 29))
 
# Horizontal Bar Plot
plt.bar(name[0:30], person_emp[0:30])
 
# Show Plot
plt.show()

# %%
name1 = df['State/UT'].head(12)
person_emp1= df['Persons Who Availed Employment (in Lakh)'].head(12)

fig = plt.figure(figsize = (20,13))
plt.bar(name1[0:10], person_emp1[0:10])

plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(x='State/UT', data=df, kde=True, hue='Persons Who Availed Employment (in Lakh)')
plt.show()
